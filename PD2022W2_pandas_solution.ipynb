# %% [markdown]
# # Preppin Data Week 2: The Prep School - Birthday Cakes

# %% [markdown]
# ### Import file
# 1. Import pandas
# 2. Import csv

# %%
import pandas as pd
df = pd.read_csv('PD 2022 Wk 1 Input - Input.csv')
df
# Out:
#        id pupil first name pupil last name  gender Date of Birth  \
# 0       1            Ronna         Nellies  Female    12/21/2013
# 1       2            Rusty       Andriulis    Male     7/21/2012
# 2       3          Roberta       Oakeshott  Female     12/4/2011
# 3       4             Lola       Rubinfajn    Male     6/29/2012
# 4       5           Kamila        Benedtti  Female     7/10/2012
# ..    ...              ...             ...     ...           ...
# 995   996          Ninetta         Worling  Female     2/15/2015
# 996   997         Stanford          Tinton  Female      4/9/2013
# 997   998            Ertha         MacCook    Male    12/14/2013
# 998   999           Lawton         Randles  Female    12/12/2011
# 999  1000         Engracia         Pashbee  Female     9/23/2013
#
#     Parental Contact Name_1 Parental Contact Name_2  \
# 0                   Purcell                   Ketti
# 1                   Vassili                    Rivi
# ...

# %% [markdown]
# 3. Remove unnecessary columns (optional step)

# %%
df = df[['id', 'pupil first name', 'pupil last name', 'Date of Birth',]]
df.head()
# Out:
#    id pupil first name pupil last name Date of Birth
# 0   1            Ronna         Nellies    12/21/2013
# 1   2            Rusty       Andriulis     7/21/2012
# 2   3          Roberta       Oakeshott     12/4/2011
# 3   4             Lola       Rubinfajn     6/29/2012
# 4   5           Kamila        Benedtti     7/10/2012

# %% [markdown]
# ### Format pupil's name in First Name Last Name format

# %%
df['Pupil Name'] = df['pupil first name'] + ' ' + df['pupil last name']
# Out:
# C:\Users\caitlin.helmer\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Create the date for the pupil's birthday in calendar year 2022
# 1. Import datetime for datetime handling
# 2. Format 'Date of Birth' as datetime

# %%
import datetime as dt
df['Date of Birth'] = pd.to_datetime(df['Date of Birth'])
# Out:
# C:\Users\caitlin.helmer\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# 3. Create separate columns to identify month and day of birthday

# %%
df['month'] = df['Date of Birth'].dt.month
df['day'] = df['Date of Birth'].dt.day
# Out:
# C:\Users\caitlin.helmer\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\caitlin.helmer\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# 4. Add a column for year (2022)

# %%
df['year'] = 2022
# Out:
# C:\Users\caitlin.helmer\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# 5. Create a single column using the three columns created in steps 3 & 4

# %%
df["This Year's Birthday"] = pd.to_datetime(dict(year=df.year, month=df.month, day=df.day))
df["This Year's Birthday"]
# Out:
# 0     2022-12-21
# 1     2022-07-21
# 2     2022-12-04
# 3     2022-06-29
# 4     2022-07-10
#          ...
# 995   2022-02-15
# 996   2022-04-09
# 997   2022-12-14
# 998   2022-12-12
# 999   2022-09-23
# Name: This Year's Birthday, Length: 1000, dtype: datetime64[ns]

# %% [markdown]
# ### Find the day of week the birthday falls on & change Saturdays and Sundays to Friday
#
# 1. Find weekday (unaltered)

# %%
df['Cake Needed On'] = df["This Year's Birthday"].dt.day_name()

# %%
df['Cake Needed On'].value_counts()
# Out:
# Sunday       166
# Thursday     155
# Wednesday    138
# Tuesday      136
# Saturday     135
# Monday       135
# Friday       135
# Name: Cake Needed On, dtype: int64

# %% [markdown]
# 2. Replace Saturday and Sunday with Friday

# %%
df['Cake Needed On'] = df['Cake Needed On'].replace(['Saturday', 'Sunday'], 'Friday')

# %%
df['Cake Needed On'].value_counts()
# Out:
# Friday       436
# Thursday     155
# Wednesday    138
# Tuesday      136
# Monday       135
# Name: Cake Needed On, dtype: int64

# %% [markdown]
# ### Find what month the pupil's birthday falls within

# %%
df['Month Name'] = df["This Year's Birthday"].dt.month_name()

# %% [markdown]
# ### Count how many birthdays there are on each weekday in each month
# 1. Create a groupby on Month Name and Cake Needed on, aggregated by count
#     - Reset the index to produce a flat dataframe rather than a multi-indexed dataframe

# %%
gb = df.groupby(['Month Name', 'Cake Needed On']).count().reset_index()
gb
# Out:
#    Month Name Cake Needed On  id  pupil first name  pupil last name  \
# 0       April         Friday  55                55               55
# 1       April         Monday  10                10               10
# 2       April       Thursday  11                11               11
# 3       April        Tuesday   4                 4                4
# 4       April      Wednesday  12                12               12
# 5      August         Friday  24                24               24
# 6      August         Monday  12                12               12
# 7      August       Thursday  10                10               10
# 8      August        Tuesday  15                15               15
# 9      August      Wednesday  10                10               10
# 10   December         Friday  45                45               45
# 11   December         Monday  20                20               20
# 12   December       Thursday  20                20               20
# ...

# %% [markdown]
# 2. Remove duplicate columns to return a single count
# 3. Rename field to reflect the fact that it is a count

# %%
gb = gb[['Month Name', 'Cake Needed On', 'id']]
gb = gb.rename(columns={'id' : 'BDs per Weekday and Month'})
gb
# Out:
#    Month Name Cake Needed On  BDs per Weekday and Month
# 0       April         Friday                         55
# 1       April         Monday                         10
# 2       April       Thursday                         11
# 3       April        Tuesday                          4
# 4       April      Wednesday                         12
# 5      August         Friday                         24
# 6      August         Monday                         12
# 7      August       Thursday                         10
# 8      August        Tuesday                         15
# 9      August      Wednesday                         10
# 10   December         Friday                         45
# 11   December         Monday                         20
# 12   December       Thursday                         20
# 13   December        Tuesday                          8
# 14   December      Wednesday                          9
# 15   February         Friday                         31
# ...

# %% [markdown]
# 4. Merge the original dataframe with the groupby on Month Name and Cake Needed On

# %%
m = pd.merge(df, gb, on=['Month Name', 'Cake Needed On'], how='left')
m
# Out:
#        id pupil first name pupil last name Date of Birth         Pupil Name  \
# 0       1            Ronna         Nellies    2013-12-21      Ronna Nellies
# 1       2            Rusty       Andriulis    2012-07-21    Rusty Andriulis
# 2       3          Roberta       Oakeshott    2011-12-04  Roberta Oakeshott
# 3       4             Lola       Rubinfajn    2012-06-29     Lola Rubinfajn
# 4       5           Kamila        Benedtti    2012-07-10    Kamila Benedtti
# ..    ...              ...             ...           ...                ...
# 995   996          Ninetta         Worling    2015-02-15    Ninetta Worling
# 996   997         Stanford          Tinton    2013-04-09    Stanford Tinton
# 997   998            Ertha         MacCook    2013-12-14      Ertha MacCook
# 998   999           Lawton         Randles    2011-12-12     Lawton Randles
# 999  1000         Engracia         Pashbee    2013-09-23   Engracia Pashbee
#
# ...

# %% [markdown]
# ### Output the data
# 1. Remove extra columns & Reorder

# %%
m = m[['Pupil Name', 'Date of Birth', "This Year's Birthday", 'Month Name', 'Cake Needed On', 'BDs per Weekday and Month']]
m.head()
# Out:
#           Pupil Name Date of Birth This Year's Birthday Month Name  \
# 0      Ronna Nellies    2013-12-21           2022-12-21   December
# 1    Rusty Andriulis    2012-07-21           2022-07-21       July
# 2  Roberta Oakeshott    2011-12-04           2022-12-04   December
# 3     Lola Rubinfajn    2012-06-29           2022-06-29       June
# 4    Kamila Benedtti    2012-07-10           2022-07-10       July
#
#   Cake Needed On  BDs per Weekday and Month
# 0      Wednesday                          9
# 1       Thursday                         12
# 2         Friday                         45
# 3      Wednesday                         15
# 4         Friday                         49

# %% [markdown]
# 2. Output to csv

# %%
m.to_csv('pandas_solution.csv', index=False)
