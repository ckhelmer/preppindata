# %% [markdown]
# # Preppin Data
#
# ## Week 25: Housing Happy Hotel Guests
#
# https://preppindata.blogspot.com/2022/06/2022-week-25-housing-happy-hotel-guests.html
#
# Note: the official solution has 217 rows (218 with headers). It does not remove excess child capacity from each of the rooms in the final step (*"Finally, for the rooms with the largest capacity, we want to ensure guests with larger parties are prioritized. Filter the data to remove parties that could fit into smaller rooms."* If you remove the excess child capacity as well, you will have 153 rows (154 with headers).

# %% [markdown]
# ### Import Pandas and Numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import dataframes

# %%
file = '2022W25 Input.xlsx'

rooms = pd.read_excel(file, sheet_name='Hotel Rooms')

rooms.head()
# Out:
#    Room  Adults  Children                          Features
# 0   101       2       NaN  Accessible, Near to lift, Double
# 1   102       2       NaN                Accessible, Double
# 2   103       2       NaN                Accessible, Double
# 3   104       2       NaN                Accessible, Double
# 4   201       2       NaN              Near to lift, Double

# %%
guests = pd.read_excel(file, sheet_name='Guests')
guests.head()
# Out:
#       Party  Adults  Children Double/Twin Requires Accessible Room?  \
# 0    Corain       4         0      Double                         N
# 1    Aarons       2         0        Twin                         N
# 2      Saph       2         1      Double                         N
# 3  Baxstare       1         1      Double                         N
# 4     Kelle       1         1        Twin                         N
#
#                   Additional Requests
# 0  Bath, High Floor, NOT Near to lift
# 1                                Bath
# 2              Bath, NOT Near to lift
# 3                    Bath, High Floor
# 4                                Bath

# %% [markdown]
# ### Make a separate column to flag each additional request a guest has
#
# Use np.where to set a new column based on the contents of a single column
#  - ie, if guests['Additional Requests'] contains 'Bath', then return 1 in the new column, else return 0
#      - use the na=False flag to return nulls as False

# %%
guests['Request Bath'] = np.where(guests['Additional Requests'].str.contains('Bath', na=False), 1, 0)

# %%
guests['Request High Floor'] = np.where(guests['Additional Requests'].str.contains('High Floor', na=False), 1, 0)

# %%
guests['Request Not Near Lift'] = np.where(guests['Additional Requests'].str.contains('lift', na=False), 1, 0)

# %% [markdown]
# ### Sum those columns to produce a column detailing how many requests a goal has

# %%
guests['Count of Requests'] = guests['Request Bath'] + guests['Request High Floor'] + guests['Request Not Near Lift']
guests['Count of Requests'].value_counts()
# Out:
# 2    15
# 1     7
# 0     6
# 3     2
# Name: Count of Requests, dtype: int64

# %% [markdown]
# ### Make separate columns to use as flags for bath, high floor, near elevator in the rooms dataframe

# %%
rooms['Bath'] = np.where(rooms['Features'].str.contains('Bath', na=False), 1, 0)

# %%
rooms['High Floor'] = np.where(rooms['Features'].str.contains('High Floor', na=False), 1, 0)

# %%
rooms['Near Lift'] = np.where(rooms['Features'].str.contains('Near to lift', na=False), 1, 0)

# %%
rooms['Double/Twin'] = np.where(rooms['Features'].str.contains('Double', na=False), 'Double', np.where(rooms['Features'].str.contains('Twin'), 'Twin', np.nan))

# %%
rooms['Accessible'] = np.where(rooms['Features'].str.contains('Accessible', na=False), 'Y', 'N')

# %% [markdown]
# ### Join the tables together so that the guests only receive the bed size of their preference
#
# Note, this will produce a table with more rows than we started with because 'Double' and 'Twin' are not unique keys. This is a memory intensive solution, so it is less than optimal.
#
# I will also be changing the names of the adults & children rows in order to preserve clarity after the join

# %%
#Rename columns using df.rename
guests = guests.rename(columns={'Adults' : 'Adults in Party', 'Children' :'Children in Party'})
guests.head()
# Out:
#       Party  Adults in Party  Children in Party Double/Twin  \
# 0    Corain                4                  0      Double
# 1    Aarons                2                  0        Twin
# 2      Saph                2                  1      Double
# 3  Baxstare                1                  1      Double
# 4     Kelle                1                  1        Twin
#
#   Requires Accessible Room?                 Additional Requests  Request Bath  \
# 0                         N  Bath, High Floor, NOT Near to lift             1
# 1                         N                                Bath             1
# 2                         N              Bath, NOT Near to lift             1
# 3                         N                    Bath, High Floor             1
# 4                         N                                Bath             1
#
#    Request High Floor  Request Not Near Lift  Count of Requests
# 0                   1                      1                  3
# 1                   0                      0                  1
# 2                   0                      1                  2
# 3                   1                      0                  2
# 4                   0                      0                  1

# %%
#Merge tables on 'Double/Twin'
join = pd.merge(guests, rooms, on='Double/Twin', how='outer', indicator=True)
join
# Out:
#        Party  Adults in Party  Children in Party Double/Twin  \
# 0     Corain                4                  0      Double
# 1     Corain                4                  0      Double
# 2     Corain                4                  0      Double
# 3     Corain                4                  0      Double
# 4     Corain                4                  0      Double
# ..       ...              ...                ...         ...
# 675  Guisler                1                  0        Twin
# 676  Guisler                1                  0        Twin
# 677  Guisler                1                  0        Twin
# 678  Guisler                1                  0        Twin
# 679  Guisler                1                  0        Twin
#
#     Requires Accessible Room?                 Additional Requests  \
# 0                           N  Bath, High Floor, NOT Near to lift
# 1                           N  Bath, High Floor, NOT Near to lift
# 2                           N  Bath, High Floor, NOT Near to lift
# 3                           N  Bath, High Floor, NOT Near to lift
# 4                           N  Bath, High Floor, NOT Near to lift
# ..                        ...                                 ...
# 675                         N  Bath, High Floor, NOT Near to lift
# 676                         N  Bath, High Floor, NOT Near to lift
# 677                         N  Bath, High Floor, NOT Near to lift
# 678                         N  Bath, High Floor, NOT Near to lift
# 679                         N  Bath, High Floor, NOT Near to lift
#
#      Request Bath  Request High Floor  Request Not Near Lift  \
# 0               1                   1                      1
# 1               1                   1                      1
# 2               1                   1                      1
# 3               1                   1                      1
# 4               1                   1                      1
# ..            ...                 ...                    ...
# 675             1                   1                      1
# 676             1                   1                      1
# 677             1                   1                      1
# 678             1                   1                      1
# 679             1                   1                      1
#
#      Count of Requests  Room  Adults  Children  \
# 0                    3   101       2       NaN
# 1                    3   102       2       NaN
# 2                    3   103       2       NaN
# 3                    3   104       2       NaN
# 4                    3   201       2       NaN
# ..                 ...   ...     ...       ...
# 675                  3   404       2       1.0
# 676                  3   405       2       NaN
# 677                  3   406       2       NaN
# 678                  3   407       2       NaN
# 679                  3   408       2       NaN
#
#                              Features  Bath  High Floor  Near Lift Accessible  \
# 0    Accessible, Near to lift, Double     0           0          1          Y
# 1                  Accessible, Double     0           0          0          Y
# 2                  Accessible, Double     0           0          0          Y
# 3                  Accessible, Double     0           0          0          Y
# 4                Near to lift, Double     0           0          1          N
# ..                                ...   ...         ...        ...        ...
# 675                  High Floor, Twin     0           1          0          N
# 676            High Floor, Bath, Twin     1           1          0          N
# 677                  High Floor, Twin     0           1          0          N
# 678            High Floor, Bath, Twin     1           1          0          N
# 679                  High Floor, Twin     0           1          0          N
#
#     _merge
# 0     both
# 1     both
# 2     both
# 3     both
# 4     both
# ..     ...
# 675   both
# 676   both
# 677   both
# 678   both
# 679   both
#
# [680 rows x 19 columns]

# %% [markdown]
# ### Filter the dataframe to keep only rows where the number of guests (adults and children) staying in the room is less than the room capacity
#
# 1. Fill blank values in the 'Children' column with 0s so they can be compared
# 2. Filter via slicing, first on adults then on children

# %%
join['Children'] = join['Children'].fillna(0)

# %%
join['Children'].value_counts()
# Out:
# 0.0    430
# 1.0    250
# Name: Children, dtype: int64

# %%
join = join[join['Adults in Party'] <= join['Adults']].copy()

# %%
join = join[join['Children in Party'] <= join['Children']].copy()

# %%
join.shape
# Out:
# (451, 19)

# %% [markdown]
# ### Ensure guests with accessibility requirements have accessible rooms
#
# 1. Split the dataframes into people who require accessible rooms and those who don't
# 2. For the people requiring accessible rooms (acc), keep only the rooms that are accessible
#     - No changes are required for the people who don't require accessible rooms
# 3. Join the two dataframes to produce the full dataset

# %%
#Split dataframes into people who require accessible rooms and those who don't

acc = join[join['Requires Accessible Room?'] == 'Y'].copy()
nacc = join[join['Requires Accessible Room?'] == 'N'].copy()

print(acc.shape)
print(nacc.shape)
# Out:
# (84, 19)
# (367, 19)

# %%
#For the accessible data frame, keep only accessible rooms

acc = acc[acc['Accessible'] == 'Y'].copy()
acc
# Out:
#          Party  Adults in Party  Children in Party Double/Twin  \
# 224     Fearby                2                  0      Double
# 225     Fearby                2                  0      Double
# 226     Fearby                2                  0      Double
# 227     Fearby                2                  0      Double
# 392    Norcutt                2                  0      Double
# 393    Norcutt                2                  0      Double
# 394    Norcutt                2                  0      Double
# 395    Norcutt                2                  0      Double
# 476  Iczokvitz                2                  0      Double
# 477  Iczokvitz                2                  0      Double
# 478  Iczokvitz                2                  0      Double
# 479  Iczokvitz                2                  0      Double
#
#     Requires Accessible Room? Additional Requests  Request Bath  \
# 224                         Y                 NaN             0
# 225                         Y                 NaN             0
# 226                         Y                 NaN             0
# 227                         Y                 NaN             0
# 392                         Y    NOT Near to lift             0
# 393                         Y    NOT Near to lift             0
# 394                         Y    NOT Near to lift             0
# 395                         Y    NOT Near to lift             0
# 476                         Y                Bath             1
# 477                         Y                Bath             1
# 478                         Y                Bath             1
# 479                         Y                Bath             1
#
#      Request High Floor  Request Not Near Lift  Count of Requests  Room  \
# 224                   0                      0                  0   101
# 225                   0                      0                  0   102
# 226                   0                      0                  0   103
# 227                   0                      0                  0   104
# 392                   0                      1                  1   101
# 393                   0                      1                  1   102
# 394                   0                      1                  1   103
# 395                   0                      1                  1   104
# 476                   0                      0                  1   101
# 477                   0                      0                  1   102
# 478                   0                      0                  1   103
# 479                   0                      0                  1   104
#
#      Adults  Children                          Features  Bath  High Floor  \
# 224       2       0.0  Accessible, Near to lift, Double     0           0
# 225       2       0.0                Accessible, Double     0           0
# 226       2       0.0                Accessible, Double     0           0
# 227       2       0.0                Accessible, Double     0           0
# 392       2       0.0  Accessible, Near to lift, Double     0           0
# 393       2       0.0                Accessible, Double     0           0
# 394       2       0.0                Accessible, Double     0           0
# 395       2       0.0                Accessible, Double     0           0
# 476       2       0.0  Accessible, Near to lift, Double     0           0
# 477       2       0.0                Accessible, Double     0           0
# 478       2       0.0                Accessible, Double     0           0
# 479       2       0.0                Accessible, Double     0           0
#
#      Near Lift Accessible _merge
# 224          1          Y   both
# 225          0          Y   both
# 226          0          Y   both
# 227          0          Y   both
# 392          1          Y   both
# 393          0          Y   both
# 394          0          Y   both
# 395          0          Y   both
# 476          1          Y   both
# 477          0          Y   both
# 478          0          Y   both
# 479          0          Y   both

# %%
#No changes are required for the nacc dataframe, so join both dataframes back together to produce the full set of possible rooms

full = nacc.append(acc)
full
# Out:
#          Party  Adults in Party  Children in Party Double/Twin  \
# 24      Corain                4                  0      Double
# 25      Corain                4                  0      Double
# 26      Corain                4                  0      Double
# 27      Corain                4                  0      Double
# 34        Saph                2                  1      Double
# ..         ...              ...                ...         ...
# 395    Norcutt                2                  0      Double
# 476  Iczokvitz                2                  0      Double
# 477  Iczokvitz                2                  0      Double
# 478  Iczokvitz                2                  0      Double
# 479  Iczokvitz                2                  0      Double
#
#     Requires Accessible Room?                 Additional Requests  \
# 24                          N  Bath, High Floor, NOT Near to lift
# 25                          N  Bath, High Floor, NOT Near to lift
# 26                          N  Bath, High Floor, NOT Near to lift
# 27                          N  Bath, High Floor, NOT Near to lift
# 34                          N              Bath, NOT Near to lift
# ..                        ...                                 ...
# 395                         Y                    NOT Near to lift
# 476                         Y                                Bath
# 477                         Y                                Bath
# 478                         Y                                Bath
# 479                         Y                                Bath
#
#      Request Bath  Request High Floor  Request Not Near Lift  \
# 24              1                   1                      1
# 25              1                   1                      1
# 26              1                   1                      1
# 27              1                   1                      1
# 34              1                   0                      1
# ..            ...                 ...                    ...
# 395             0                   0                      1
# 476             1                   0                      0
# 477             1                   0                      0
# 478             1                   0                      0
# 479             1                   0                      0
#
#      Count of Requests  Room  Adults  Children  \
# 24                   3   601       4       0.0
# 25                   3   602       4       0.0
# 26                   3   603       4       0.0
# 27                   3   604       4       0.0
# 34                   2   203       2       1.0
# ..                 ...   ...     ...       ...
# 395                  1   104       2       0.0
# 476                  1   101       2       0.0
# 477                  1   102       2       0.0
# 478                  1   103       2       0.0
# 479                  1   104       2       0.0
#
#                                    Features  Bath  High Floor  Near Lift  \
# 24   High Floor, Bath, Near to lift, Double     1           1          1
# 25                 High Floor, Bath, Double     1           1          0
# 26                 High Floor, Bath, Double     1           1          0
# 27                 High Floor, Bath, Double     1           1          0
# 34                                   Double     0           0          0
# ..                                      ...   ...         ...        ...
# 395                      Accessible, Double     0           0          0
# 476        Accessible, Near to lift, Double     0           0          1
# 477                      Accessible, Double     0           0          0
# 478                      Accessible, Double     0           0          0
# 479                      Accessible, Double     0           0          0
#
#     Accessible _merge
# 24           N   both
# 25           N   both
# 26           N   both
# 27           N   both
# 34           N   both
# ..         ...    ...
# 395          Y   both
# 476          Y   both
# 477          Y   both
# 478          Y   both
# 479          Y   both
#
# [379 rows x 19 columns]

# %% [markdown]
# ### Calculate the request satisfaction % for each guest in each room
#
# 1. Using df.apply() assess wither the Request columns match the 'Features' columns
#     1. First, write a function to use with df.apply().
#         - You will write three functions, one to use with bath, high floor, and not near lift
#     2. Use df.apply on the dataframe to call the functions
# 2. Sum the resulting columns to find out how many matching requests the guests had. This column is called 'Requirements Met'
# 3. Divide the 'Requirements Met' column by the 'Count of Requests' column. Round and multiply by 100 to produce a percent
#     - Guests who have zero requests will result in a NaN, due to revising by zero. Fill this with 0 using series.fillna()

# %%
#Calculate whether each column is matched (or irrelevant)

#Bath match
def bath(x):
    if x['Request Bath'] == 1 and x['Bath'] == 1.0:
        return 1
    else:
        return 0
    
#High Floor
def hf(x):
    if x['Request High Floor'] == 1 and x['High Floor'] == 1.0:
        return 1
    else:
        return 0

#Not near lift
def nnl(x):
    if x['Request Not Near Lift'] == 1 and x['Near Lift'] == 0.0:
        return 1
    else:
        return 0

# %%
#Produce new columns to state whether these are a match

full['match_bath'] = full.apply(bath, axis=1)
full['match_bath'].value_counts()
# Out:
# 0    271
# 1    108
# Name: match_bath, dtype: int64

# %%
full['match_hf'] = full.apply(hf, axis=1)
full['match_hf'].value_counts()
# Out:
# 0    271
# 1    108
# Name: match_hf, dtype: int64

# %%
full['Near Lift'].value_counts()
# Out:
# 0    323
# 1     56
# Name: Near Lift, dtype: int64

# %%
full['match_nnl'] = full.apply(nnl, axis=1)
full['match_nnl'].value_counts()
# Out:
# 0    262
# 1    117
# Name: match_nnl, dtype: int64

# %%
#Sum match columns

full['Requirements Met'] = full['match_bath'] + full['match_hf'] + full['match_nnl']
full['Requirements Met'].value_counts()
# Out:
# 0    150
# 1    131
# 2     92
# 3      6
# Name: Requirements Met, dtype: int64

# %%
#Divide sum match columns by number of requests to produce percentage

full['Request Satisfaction'] = round(full['Requirements Met']/full['Count of Requests'], 4) * 100
full['Request Satisfaction']
# Out:
# 24      66.67
# 25     100.00
# 26     100.00
# 27     100.00
# 34      50.00
#         ...
# 395    100.00
# 476      0.00
# 477      0.00
# 478      0.00
# 479      0.00
# Name: Request Satisfaction, Length: 379, dtype: float64

# %%
#Fill NaNs resulting from dividing by zero above with 0

full['Request Satisfaction'] = full['Request Satisfaction'].fillna(0)

# %% [markdown]
# ### Filter so that guests are left only with the highest request satisfaction
#
# 1. Create a smaller dataset containing only the 'Party' and 'Request Satisfaction' fields.
# 2. Create a groupby sorted on the maximum of request satisfaction
# 3. Join the small groupby back to the full dataset on both 'Party' and 'Request Satisfaction', using a left join to only keep the maximum of request satisfaction

# %%
#Create a smaller database
gb = full[['Party', 'Request Satisfaction']]

# %%
#Create a groubpy on party with the maximum of request satisfaction
gb = gb.groupby('Party').max()
gb
# Out:
#                 Request Satisfaction
# Party
# Aarons                         100.0
# Abramowitz                     100.0
# Baxstare                       100.0
# Chese                          100.0
# Corain                         100.0
# Cullum                           0.0
# Fallens                          0.0
# Fearby                           0.0
# Gendrich                       100.0
# Ghiriardelli                   100.0
# Gubbins                        100.0
# Guisler                        100.0
# Henriquet                      100.0
# Iczokvitz                        0.0
# Jeannel                        100.0
# Jirousek                       100.0
# Josefer                        100.0
# Kelle                          100.0
# Krishtopaittis                   0.0
# Lansdale                       100.0
# Londer                         100.0
# Marusik                        100.0
# Norcutt                        100.0
# O'Hare                           0.0
# Rozzier                        100.0
# Saph                           100.0
# Segeswoeth                     100.0
# Sumers                           0.0
# Vowell                         100.0
# Winmill                        100.0

# %%
### Join the Groupby to the full dataframe to keep only the highest rooms

full2 = pd.merge(gb, full, on=['Party', 'Request Satisfaction'], how='left')
full2
# Out:
#        Party  Request Satisfaction  Adults in Party  Children in Party  \
# 0     Aarons                 100.0                2                  0
# 1     Aarons                 100.0                2                  0
# 2     Aarons                 100.0                2                  0
# 3     Aarons                 100.0                2                  0
# 4     Aarons                 100.0                2                  0
# ..       ...                   ...              ...                ...
# 237   Vowell                 100.0                4                  0
# 238  Winmill                 100.0                1                  1
# 239  Winmill                 100.0                1                  1
# 240  Winmill                 100.0                1                  1
# 241  Winmill                 100.0                1                  1
#
#     Double/Twin Requires Accessible Room?           Additional Requests  \
# 0          Twin                         N                          Bath
# 1          Twin                         N                          Bath
# 2          Twin                         N                          Bath
# 3          Twin                         N                          Bath
# 4          Twin                         N                          Bath
# ..          ...                       ...                           ...
# 237      Double                         N  High Floor, NOT Near to lift
# 238      Double                         N  High Floor, NOT Near to lift
# 239      Double                         N  High Floor, NOT Near to lift
# 240      Double                         N  High Floor, NOT Near to lift
# 241      Double                         N  High Floor, NOT Near to lift
#
#      Request Bath  Request High Floor  Request Not Near Lift  ...  \
# 0               1                   0                      0  ...
# 1               1                   0                      0  ...
# 2               1                   0                      0  ...
# 3               1                   0                      0  ...
# 4               1                   0                      0  ...
# ..            ...                 ...                    ...  ...
# 237             0                   1                      1  ...
# 238             0                   1                      1  ...
# 239             0                   1                      1  ...
# 240             0                   1                      1  ...
# 241             0                   1                      1  ...
#
#                                  Features  Bath  High Floor  Near Lift  \
# 0                              Bath, Twin     1           0          0
# 1                              Bath, Twin     1           0          0
# 2                              Bath, Twin     1           0          0
# 3    High Floor, Bath, Near to lift, Twin     1           1          1
# 4                  High Floor, Bath, Twin     1           1          0
# ..                                    ...   ...         ...        ...
# 237              High Floor, Bath, Double     1           1          0
# 238              High Floor, Bath, Double     1           1          0
# 239              High Floor, Bath, Double     1           1          0
# 240              High Floor, Bath, Double     1           1          0
# 241              High Floor, Bath, Double     1           1          0
#
#     Accessible  _merge  match_bath  match_hf match_nnl Requirements Met
# 0            N    both           1         0         0                1
# 1            N    both           1         0         0                1
# 2            N    both           1         0         0                1
# 3            N    both           1         0         0                1
# 4            N    both           1         0         0                1
# ..         ...     ...         ...       ...       ...              ...
# 237          N    both           0         1         1                2
# 238          N    both           0         1         1                2
# 239          N    both           0         1         1                2
# 240          N    both           0         1         1                2
# 241          N    both           0         1         1                2
#
# [242 rows x 24 columns]

# %% [markdown]
# ### Remove rooms that are too large for the party
#
# 1. Remove the request columns. (This is not strictly necessary to do in this order.)
# 2. For each child and adult capacity, we will create a groupby that contains the minimum size of the room needed for each party
#     1. For adults, create a smaller df with only Party and Adults (room capacity) information
#     2. Produce a groupby to take the minimum. Use reset index to produce a flat df rather than an hierarchical index.
#     3. Repeat steps 1 and 2 for Children
#     4. Combine these two groupbys using pd.merge()
# 3. Join the capacity dataframe created during step 2 with the full dataframe from the cleanup step. This results in the solution for the exercise.

# %%
#Clean up extra columns

full2 = full2[['Party',  'Adults in Party', 'Children in Party',
       'Double/Twin', 'Requires Accessible Room?', 'Additional Requests',
       'Request Satisfaction',  'Room', 'Adults', 'Children', 'Features']]
full2
# Out:
#        Party  Adults in Party  Children in Party Double/Twin  \
# 0     Aarons                2                  0        Twin
# 1     Aarons                2                  0        Twin
# 2     Aarons                2                  0        Twin
# 3     Aarons                2                  0        Twin
# 4     Aarons                2                  0        Twin
# ..       ...              ...                ...         ...
# 237   Vowell                4                  0      Double
# 238  Winmill                1                  1      Double
# 239  Winmill                1                  1      Double
# 240  Winmill                1                  1      Double
# 241  Winmill                1                  1      Double
#
#     Requires Accessible Room?           Additional Requests  \
# 0                           N                          Bath
# 1                           N                          Bath
# 2                           N                          Bath
# 3                           N                          Bath
# 4                           N                          Bath
# ..                        ...                           ...
# 237                         N  High Floor, NOT Near to lift
# 238                         N  High Floor, NOT Near to lift
# 239                         N  High Floor, NOT Near to lift
# 240                         N  High Floor, NOT Near to lift
# 241                         N  High Floor, NOT Near to lift
#
#      Request Satisfaction  Room  Adults  Children  \
# 0                   100.0   302       2       1.0
# 1                   100.0   303       2       0.0
# 2                   100.0   304       2       1.0
# 3                   100.0   401       2       0.0
# 4                   100.0   402       2       1.0
# ..                    ...   ...     ...       ...
# 237                 100.0   604       4       0.0
# 238                 100.0   503       2       1.0
# 239                 100.0   504       2       1.0
# 240                 100.0   506       2       1.0
# 241                 100.0   507       2       1.0
#
#                                  Features
# 0                              Bath, Twin
# 1                              Bath, Twin
# 2                              Bath, Twin
# 3    High Floor, Bath, Near to lift, Twin
# 4                  High Floor, Bath, Twin
# ..                                    ...
# 237              High Floor, Bath, Double
# 238              High Floor, Bath, Double
# 239              High Floor, Bath, Double
# 240              High Floor, Bath, Double
# 241              High Floor, Bath, Double
#
# [242 rows x 11 columns]

# %%
#Create a groupby that keeps only the minimum size of the room for adults

gb2 = full2[['Party', 'Adults']]
gb2 = gb2.groupby(by='Party').min().reset_index()
gb2
# Out:
#              Party  Adults
# 0           Aarons       2
# 1       Abramowitz       2
# 2         Baxstare       2
# 3            Chese       2
# 4           Corain       4
# 5           Cullum       2
# 6          Fallens       2
# 7           Fearby       2
# 8         Gendrich       4
# 9     Ghiriardelli       2
# 10         Gubbins       2
# 11         Guisler       2
# 12       Henriquet       2
# 13       Iczokvitz       2
# 14         Jeannel       2
# 15        Jirousek       2
# 16         Josefer       2
# 17           Kelle       2
# 18  Krishtopaittis       2
# 19        Lansdale       2
# 20          Londer       2
# 21         Marusik       2
# 22         Norcutt       2
# 23          O'Hare       2
# 24         Rozzier       2
# 25            Saph       2
# 26      Segeswoeth       4
# 27          Sumers       2
# 28          Vowell       4
# 29         Winmill       2

# %%
#Create a groupby that keeps only the minimum size of the room for children

gb3 = full2[['Party', 'Children']]
gb3 = gb3.groupby(by='Party').min().reset_index()
gb3
# Out:
#              Party  Children
# 0           Aarons       0.0
# 1       Abramowitz       1.0
# 2         Baxstare       1.0
# 3            Chese       0.0
# 4           Corain       0.0
# 5           Cullum       0.0
# 6          Fallens       0.0
# 7           Fearby       0.0
# 8         Gendrich       0.0
# 9     Ghiriardelli       0.0
# 10         Gubbins       0.0
# 11         Guisler       0.0
# 12       Henriquet       1.0
# 13       Iczokvitz       0.0
# 14         Jeannel       0.0
# 15        Jirousek       0.0
# 16         Josefer       1.0
# 17           Kelle       1.0
# 18  Krishtopaittis       0.0
# 19        Lansdale       0.0
# 20          Londer       0.0
# 21         Marusik       0.0
# 22         Norcutt       0.0
# 23          O'Hare       1.0
# 24         Rozzier       0.0
# 25            Saph       1.0
# 26      Segeswoeth       0.0
# 27          Sumers       0.0
# 28          Vowell       0.0
# 29         Winmill       1.0

# %%
#Join the adults and children groupbys together

gb4 = pd.merge(gb2, gb3, on='Party')
gb4
# Out:
#              Party  Adults  Children
# 0           Aarons       2       0.0
# 1       Abramowitz       2       1.0
# 2         Baxstare       2       1.0
# 3            Chese       2       0.0
# 4           Corain       4       0.0
# 5           Cullum       2       0.0
# 6          Fallens       2       0.0
# 7           Fearby       2       0.0
# 8         Gendrich       4       0.0
# 9     Ghiriardelli       2       0.0
# 10         Gubbins       2       0.0
# 11         Guisler       2       0.0
# 12       Henriquet       2       1.0
# 13       Iczokvitz       2       0.0
# 14         Jeannel       2       0.0
# 15        Jirousek       2       0.0
# 16         Josefer       2       1.0
# 17           Kelle       2       1.0
# 18  Krishtopaittis       2       0.0
# 19        Lansdale       2       0.0
# 20          Londer       2       0.0
# 21         Marusik       2       0.0
# 22         Norcutt       2       0.0
# 23          O'Hare       2       1.0
# 24         Rozzier       2       0.0
# 25            Saph       2       1.0
# 26      Segeswoeth       4       0.0
# 27          Sumers       2       0.0
# 28          Vowell       4       0.0
# 29         Winmill       2       1.0

# %%
#Join the combined minimum groupby with the full2 groupby

full3 = pd.merge(gb4, full2, on=['Party', 'Adults','Children'], how='left')
full3
# Out:
#           Party  Adults  Children  Adults in Party  Children in Party  \
# 0        Aarons       2       0.0                2                  0
# 1        Aarons       2       0.0                2                  0
# 2        Aarons       2       0.0                2                  0
# 3        Aarons       2       0.0                2                  0
# 4    Abramowitz       2       1.0                2                  1
# ..          ...     ...       ...              ...                ...
# 148      Vowell       4       0.0                4                  0
# 149     Winmill       2       1.0                1                  1
# 150     Winmill       2       1.0                1                  1
# 151     Winmill       2       1.0                1                  1
# 152     Winmill       2       1.0                1                  1
#
#     Double/Twin Requires Accessible Room?           Additional Requests  \
# 0          Twin                         N                          Bath
# 1          Twin                         N                          Bath
# 2          Twin                         N                          Bath
# 3          Twin                         N                          Bath
# 4        Double                         N              Bath, High Floor
# ..          ...                       ...                           ...
# 148      Double                         N  High Floor, NOT Near to lift
# 149      Double                         N  High Floor, NOT Near to lift
# 150      Double                         N  High Floor, NOT Near to lift
# 151      Double                         N  High Floor, NOT Near to lift
# 152      Double                         N  High Floor, NOT Near to lift
#
#      Request Satisfaction  Room                                Features
# 0                   100.0   303                              Bath, Twin
# 1                   100.0   401    High Floor, Bath, Near to lift, Twin
# 2                   100.0   405                  High Floor, Bath, Twin
# 3                   100.0   407                  High Floor, Bath, Twin
# 4                   100.0   501  High Floor, Bath, Near to lift, Double
# ..                    ...   ...                                     ...
# 148                 100.0   604                High Floor, Bath, Double
# 149                 100.0   503                High Floor, Bath, Double
# 150                 100.0   504                High Floor, Bath, Double
# 151                 100.0   506                High Floor, Bath, Double
# 152                 100.0   507                High Floor, Bath, Double
#
# [153 rows x 11 columns]

# %% [markdown]
# ### Export to csv

# %%
full3.to_csv('pandas_output.csv', index=False)
